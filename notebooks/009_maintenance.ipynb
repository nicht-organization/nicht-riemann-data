# %%
repo_base = "nicht-riemann-data"
# !git clone https://github.com/nicht-organization/{repo_base}.git
# %cd /content/{repo_base} && ls -alltr

# %%
from google.colab import userdata
repo_base = "nicht-riemann-data"
# %cd {repo_base}

git_name = userdata.get('GIT_AUTHOR_NAME')
git_email = userdata.get('GIT_AUTHOR_EMAIL')
github_token = userdata.get('GITHUB_TOKEN')

# !git config user.name "{git_name}"
# !git config user.email "{git_email}"

push_url = f"https://{github_token}@github.com/nicht-organization/{repo_base}.git"

# !git add ...

commit_msg = "..."
# !git commit -m "{commit_msg}"

# !git push {push_url} {branch_name}}


print("\nerfolgreich gepusht!")
